# %% [markdown]
# # <u>**Part 01**

# %% [markdown]
# A namespace is a collection of currently defined names along with information about the object that each name references.We can think of a namespace as a dictionary in which the keys are the object names and the values are the objects themselves. Each key-value pair maps a name to its corresponding object.
#
# In a Python program, there are four types of namespaces:
#
# 1. Built-In
# 2. Global
# 3. Enclosing
# 4. Local

# %% [markdown]
# ### **Exercise 1**
#
#
# Import the built-in datetime module and display the namespace of this module (sorted alphabetically).

# %%
import datetime

for name in sorted(datetime.__dict__):
    print(name)
# Out:
# MAXYEAR
# MINYEAR
# __all__
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __spec__
# date
# datetime
# datetime_CAPI
# sys
# time
# timedelta
# timezone
# tzinfo

# %% [markdown]
# ### **Exercise 2**
#
# The product class is given below

# %%
import uuid


class Product:

    def __init__(self, product_name, price):
        self.product_id = self.get_id()
        self.product_name = product_name
        self.price = price

    def __repr__(self):
        return (
            f"Product(product_name='{self.product_name}', "
            f"price={self.price})"
        )

    @staticmethod
    def get_id():
        return str(uuid.uuid4().fields[-1])[:6]

# %% [markdown]
# Display the namespace (value of the `__dict__` attribute) of this class as shown below.

# %%
for name in Product.__dict__:
    print(name)
# Out:
# __module__
# __init__
# __repr__
# get_id
# __dict__
# __weakref__
# __doc__

# %% [markdown]
# ### **Exercise 3**
#
# The product class is specified.

# %%
class Product:

    def __init__(self, product_name, product_id, price):
        self.product_name = product_name
        self.product_id = product_id
        self.price = price

    def __repr__(self):
        return (
            f"Product(product_name='{self.product_name}', "
            f"price={self.price})"
        )


product = Product('Mobile Phone', '54274', 2900)

# %% [markdown]
# Display the namespace (value of the `__dict__` attribute) of this instance as shown below.

# %%
product.__dict__
# Out:
# {'product_name': 'Mobile Phone', 'product_id': '54274', 'price': 2900}
